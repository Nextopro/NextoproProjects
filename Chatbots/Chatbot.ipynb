# %%
#pip install tensorflow, keras, pickle, nltk

# %%
# import nltk
# nltk.download('all')

# %%
import warnings
warnings.filterwarnings("ignore")

# %%
import nltk
from nltk.stem import WordNetLemmatizer
lemmatizer = WordNetLemmatizer()
import json
import pickle

import numpy as np
from keras.models import Sequential
from keras.layers import Dense, Activation, Dropout
from tensorflow.keras.optimizers import SGD
import random

# %%
words=[]
classes = []
documents = []
ignore_words = ['?', '!']
data_file = open('intents.json').read()
intents = json.loads(data_file)

# %%
for intent in intents['intents']:
    for pattern in intent['patterns']:
        #tokenize each word
        w = nltk.word_tokenize(pattern)
        words.extend(w)
        #add documents in the corpus
        documents.append((w, intent['tag']))
        # add to our classes list
        if intent['tag'] not in classes:
            classes.append(intent['tag'])

# %%
# lemmatize, lower each word and remove duplicates
words = [lemmatizer.lemmatize(w.lower()) for w in words if w not in ignore_words]
words = sorted(list(set(words)))
# sort classes
classes = sorted(list(set(classes)))
# documents = combination between patterns and intents
print (len(documents), "documents")
# classes = intents
print (len(classes), "classes", classes)
# words = all words, vocabulary
print (len(words), "unique lemmatized words", words)
pickle.dump(words,open('words.pkl','wb'))
pickle.dump(classes,open('classes.pkl','wb'))
# Out:
# 51 documents
# 11 classes ['adverse_drug', 'blood_pressure', 'blood_pressure_search', 'goodbye', 'greeting', 'hospital_search', 'options', 'pharmacy_search', 'question', 'reply', 'thanks']
# 91 unique lemmatized words ["'m", "'s", ',', 'a', 'adverse', 'all', 'am', 'anyone', 'are', 'awesome', 'be', 'behavior', 'blood', 'by', 'bye', 'can', 'causing', 'chatting', 'check', 'could', 'data', 'day', 'detail', 'do', 'dont', 'drug', 'entry', 'find', 'for', 'fyn', 'give', 'good', 'goodbye', 'have', 'hello', 'help', 'helpful', 'helping', 'hey', 'hi', 'history', 'hola', 'hospital', 'how', 'i', 'id', 'is', 'later', 'list', 'load', 'locate', 'log', 'looking', 'lookup', 'management', 'me', 'module', 'nearby', 'next', 'nice', 'of', 'offered', 'open', 'patient', 'pharmacy', 'pressure', 'provide', 'reaction', 'related', 'result', 'search', 'searching', 'see', 'show', 'suitable', 'support', 'task', 'thank', 'thanks', 'that', 'there', 'till', 'time', 'to', 'transfer', 'up', 'want', 'what', 'which', 'with', 'you']

# %%
# create our training data
training = []
# create an empty array for our output
output_empty = [0] * len(classes)
# training set, bag of words for each sentence
for doc in documents:
    # initialize our bag of words
    bag = []
    # list of tokenized words for the pattern
    pattern_words = doc[0]
    # lemmatize each word - create base word, in attempt to represent related words
    pattern_words = [lemmatizer.lemmatize(word.lower()) for word in pattern_words]
    # create our bag of words array with 1, if word match found in current pattern
    for w in words:
        bag.append(1) if w in pattern_words else bag.append(0)
    # output is a '0' for each tag and '1' for current tag (for each pattern)
    output_row = list(output_empty)
    output_row[classes.index(doc[1])] = 1
    training.append([bag, output_row])
# shuffle our features and turn into np.array
random.shuffle(training)
training = np.array(training)
# create train and test lists. X - patterns, Y - intents
train_x = list(training[:,0])
train_y = list(training[:,1])
print("Training data created")
# Out:
# Training data created

# %%
# Create model - 3 layers. First layer 128 neurons, second layer 64 neurons and 3rd output layer contains number of neurons
# equal to number of intents to predict output intent with softmax
model = Sequential()
model.add(Dense(128, input_shape=(len(train_x[0]),), activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(64, activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(len(train_y[0]), activation='softmax'))
# Compile model. Stochastic gradient descent with Nesterov accelerated gradient gives good results for this model
sgd = SGD(lr=0.01, decay=1e-6, momentum=0.9, nesterov=True)
model.compile(loss='categorical_crossentropy', optimizer=sgd, metrics=['accuracy'])
#fitting and saving the model 
hist = model.fit(np.array(train_x), np.array(train_y), epochs=200, batch_size=5, verbose=1)
model.save('chatbot_model.h5', hist)
print("model created")
# Out:
# Epoch 1/200
# 11/11 [==============================] - 1s 2ms/step - loss: 2.3567 - accuracy: 0.1373
# Epoch 2/200
# 11/11 [==============================] - 0s 3ms/step - loss: 2.3850 - accuracy: 0.1569
# Epoch 3/200
# 11/11 [==============================] - 0s 3ms/step - loss: 2.2552 - accuracy: 0.2941
# Epoch 4/200
# 11/11 [==============================] - 0s 3ms/step - loss: 2.2055 - accuracy: 0.3137
# Epoch 5/200
# 11/11 [==============================] - 0s 3ms/step - loss: 2.0957 - accuracy: 0.2941
# Epoch 6/200
# 11/11 [==============================] - 0s 3ms/step - loss: 1.9624 - accuracy: 0.4706
# Epoch 7/200
# 11/11 [==============================] - 0s 3ms/step - loss: 1.8158 - accuracy: 0.6078
# Epoch 8/200
# 11/11 [==============================] - 0s 3ms/step - loss: 1.6928 - accuracy: 0.5686
# Epoch 9/200
# 11/11 [==============================] - 0s 3ms/step - loss: 1.5542 - accuracy: 0.5490
# Epoch 10/200
# 11/11 [==============================] - 0s 3ms/step - loss: 1.3753 - accuracy: 0.6275
# Epoch 11/200
# 11/11 [==============================] - 0s 3ms/step - loss: 1.2237 - accuracy: 0.7451
# Epoch 12/200
# 11/11 [==============================] - 0s 3ms/step - loss: 1.2257 - accuracy: 0.6471
# Epoch 13/200
# 11/11 [==============================] - 0s 3ms/step - loss: 0.9933 - accuracy: 0.7843
# Epoch 14/200
# 11/11 [==============================] - 0s 3ms/step - loss: 1.0066 - accuracy: 0.6863
# Epoch 15/200
# 11/11 [==============================] - 0s 3ms/step - loss: 0.7846 - accuracy: 0.8431
# Epoch 16/200
# 11/11 [==============================] - 0s 3ms/step - loss: 0.7847 - accuracy: 0.8039
# Epoch 17/200
# 11/11 [==============================] - 0s 3ms/step - loss: 0.6612 - accuracy: 0.8824
# Epoch 18/200
# 11/11 [==============================] - 0s 3ms/step - loss: 0.7336 - accuracy: 0.8039
# Epoch 19/200
# 11/11 [==============================] - 0s 3ms/step - loss: 0.5874 - accuracy: 0.9020
# Epoch 20/200
# 11/11 [==============================] - 0s 3ms/step - loss: 0.5848 - accuracy: 0.8235
# Epoch 21/200
# 11/11 [==============================] - 0s 3ms/step - loss: 0.7104 - accuracy: 0.7451
# Epoch 22/200
# 11/11 [==============================] - 0s 3ms/step - loss: 0.5344 - accuracy: 0.8431
# Epoch 23/200
# 11/11 [==============================] - 0s 3ms/step - loss: 0.4079 - accuracy: 0.9412
# Epoch 24/200
# 11/11 [==============================] - 0s 3ms/step - loss: 0.4268 - accuracy: 0.8627
# Epoch 25/200
# 11/11 [==============================] - 0s 3ms/step - loss: 0.4852 - accuracy: 0.8039
# Epoch 26/200
# 11/11 [==============================] - 0s 3ms/step - loss: 0.3671 - accuracy: 0.8824
# Epoch 27/200
# 11/11 [==============================] - 0s 3ms/step - loss: 0.3417 - accuracy: 0.9020
# Epoch 28/200
# 11/11 [==============================] - 0s 2ms/step - loss: 0.4184 - accuracy: 0.9216
# Epoch 29/200
# 11/11 [==============================] - 0s 3ms/step - loss: 0.4354 - accuracy: 0.8627
# Epoch 30/200
# 11/11 [==============================] - 0s 3ms/step - loss: 0.3802 - accuracy: 0.9216
# Epoch 31/200
# 11/11 [==============================] - 0s 3ms/step - loss: 0.3301 - accuracy: 0.8824
# Epoch 32/200
# 11/11 [==============================] - 0s 3ms/step - loss: 0.3806 - accuracy: 0.8824
# Epoch 33/200
# 11/11 [==============================] - 0s 3ms/step - loss: 0.2286 - accuracy: 0.9608
# Epoch 34/200
# 11/11 [==============================] - 0s 3ms/step - loss: 0.2521 - accuracy: 0.9804
# Epoch 35/200
# 11/11 [==============================] - 0s 3ms/step - loss: 0.1672 - accuracy: 0.9804
# Epoch 36/200
# 11/11 [==============================] - 0s 2ms/step - loss: 0.2358 - accuracy: 0.9412
# Epoch 37/200
# 11/11 [==============================] - 0s 3ms/step - loss: 0.2142 - accuracy: 0.9608
# Epoch 38/200
# 11/11 [==============================] - 0s 3ms/step - loss: 0.2146 - accuracy: 0.9608
# Epoch 39/200
# 11/11 [==============================] - 0s 2ms/step - loss: 0.2414 - accuracy: 0.9216
# Epoch 40/200
# 11/11 [==============================] - 0s 2ms/step - loss: 0.2013 - accuracy: 0.9412
# Epoch 41/200
# 11/11 [==============================] - 0s 3ms/step - loss: 0.2343 - accuracy: 0.9020
# Epoch 42/200
# 11/11 [==============================] - 0s 3ms/step - loss: 0.2383 - accuracy: 0.9216
# Epoch 43/200
# 11/11 [==============================] - 0s 3ms/step - loss: 0.2063 - accuracy: 0.9412
# Epoch 44/200
# 11/11 [==============================] - 0s 3ms/step - loss: 0.1102 - accuracy: 0.9804
# Epoch 45/200
# 11/11 [==============================] - 0s 3ms/step - loss: 0.3071 - accuracy: 0.9216
# Epoch 46/200
# 11/11 [==============================] - 0s 3ms/step - loss: 0.5182 - accuracy: 0.9412
# Epoch 47/200
# 11/11 [==============================] - 0s 3ms/step - loss: 0.3626 - accuracy: 0.9020
# Epoch 48/200
# 11/11 [==============================] - 0s 2ms/step - loss: 0.2366 - accuracy: 0.9412
# Epoch 49/200
# 11/11 [==============================] - 0s 3ms/step - loss: 0.1127 - accuracy: 0.9804
# Epoch 50/200
# 11/11 [==============================] - 0s 2ms/step - loss: 0.1735 - accuracy: 1.0000
# Epoch 51/200
# 11/11 [==============================] - 0s 3ms/step - loss: 0.1445 - accuracy: 0.9608
# Epoch 52/200
# 11/11 [==============================] - 0s 3ms/step - loss: 0.1705 - accuracy: 0.9412
# Epoch 53/200
# 11/11 [==============================] - 0s 3ms/step - loss: 0.2044 - accuracy: 0.9216
# Epoch 54/200
# 11/11 [==============================] - 0s 3ms/step - loss: 0.1343 - accuracy: 0.9608
# Epoch 55/200
# 11/11 [==============================] - 0s 2ms/step - loss: 0.0578 - accuracy: 1.0000
# Epoch 56/200
# 11/11 [==============================] - 0s 2ms/step - loss: 0.0972 - accuracy: 0.9804
# Epoch 57/200
# 11/11 [==============================] - 0s 2ms/step - loss: 0.1550 - accuracy: 0.9412
# Epoch 58/200
# 11/11 [==============================] - 0s 2ms/step - loss: 0.0874 - accuracy: 0.9608
# Epoch 59/200
# 11/11 [==============================] - 0s 2ms/step - loss: 0.1367 - accuracy: 0.9412
# Epoch 60/200
# 11/11 [==============================] - 0s 2ms/step - loss: 0.0559 - accuracy: 1.0000
# Epoch 61/200
# 11/11 [==============================] - 0s 3ms/step - loss: 0.1034 - accuracy: 0.9608
# Epoch 62/200
# 11/11 [==============================] - 0s 3ms/step - loss: 0.1014 - accuracy: 1.0000
# Epoch 63/200
# 11/11 [==============================] - 0s 3ms/step - loss: 0.0996 - accuracy: 0.9804
# Epoch 64/200
# 11/11 [==============================] - 0s 4ms/step - loss: 0.1034 - accuracy: 0.9804
# Epoch 65/200
# 11/11 [==============================] - 0s 2ms/step - loss: 0.0562 - accuracy: 1.0000
# Epoch 66/200
# 11/11 [==============================] - 0s 2ms/step - loss: 0.0756 - accuracy: 0.9804
# Epoch 67/200
# 11/11 [==============================] - 0s 2ms/step - loss: 0.1126 - accuracy: 0.9608
# Epoch 68/200
# 11/11 [==============================] - 0s 2ms/step - loss: 0.0504 - accuracy: 1.0000
# Epoch 69/200
# 11/11 [==============================] - 0s 3ms/step - loss: 0.1123 - accuracy: 0.9804
# Epoch 70/200
# 11/11 [==============================] - 0s 3ms/step - loss: 0.1110 - accuracy: 0.9804
# Epoch 71/200
# 11/11 [==============================] - 0s 3ms/step - loss: 0.0610 - accuracy: 0.9804
# Epoch 72/200
# 11/11 [==============================] - 0s 3ms/step - loss: 0.1162 - accuracy: 0.9608
# Epoch 73/200
# 11/11 [==============================] - 0s 3ms/step - loss: 0.1524 - accuracy: 0.9804
# Epoch 74/200
# 11/11 [==============================] - 0s 3ms/step - loss: 0.1044 - accuracy: 0.9608
# Epoch 75/200
# 11/11 [==============================] - 0s 3ms/step - loss: 0.0808 - accuracy: 0.9608
# Epoch 76/200
# 11/11 [==============================] - 0s 3ms/step - loss: 0.0704 - accuracy: 0.9804
# Epoch 77/200
# 11/11 [==============================] - 0s 3ms/step - loss: 0.1384 - accuracy: 0.9608
# Epoch 78/200
# 11/11 [==============================] - 0s 3ms/step - loss: 0.0844 - accuracy: 1.0000
# Epoch 79/200
# 11/11 [==============================] - 0s 2ms/step - loss: 0.0899 - accuracy: 0.9804
# Epoch 80/200
# 11/11 [==============================] - 0s 3ms/step - loss: 0.0520 - accuracy: 1.0000
# Epoch 81/200
# 11/11 [==============================] - 0s 3ms/step - loss: 0.0862 - accuracy: 0.9804
# Epoch 82/200
# 11/11 [==============================] - 0s 2ms/step - loss: 0.1210 - accuracy: 0.9804
# Epoch 83/200
# 11/11 [==============================] - 0s 2ms/step - loss: 0.0787 - accuracy: 0.9804
# Epoch 84/200
# 11/11 [==============================] - 0s 3ms/step - loss: 0.0283 - accuracy: 1.0000
# Epoch 85/200
# 11/11 [==============================] - 0s 3ms/step - loss: 0.1626 - accuracy: 0.9608
# Epoch 86/200
# 11/11 [==============================] - 0s 2ms/step - loss: 0.0693 - accuracy: 0.9804
# Epoch 87/200
# 11/11 [==============================] - 0s 3ms/step - loss: 0.0692 - accuracy: 1.0000
# Epoch 88/200
# 11/11 [==============================] - 0s 3ms/step - loss: 0.0599 - accuracy: 1.0000
# Epoch 89/200
# 11/11 [==============================] - 0s 3ms/step - loss: 0.0167 - accuracy: 1.0000
# Epoch 90/200
# 11/11 [==============================] - 0s 3ms/step - loss: 0.0935 - accuracy: 1.0000
# Epoch 91/200
# 11/11 [==============================] - 0s 3ms/step - loss: 0.0230 - accuracy: 1.0000
# Epoch 92/200
# 11/11 [==============================] - 0s 3ms/step - loss: 0.0496 - accuracy: 1.0000
# Epoch 93/200
# 11/11 [==============================] - 0s 3ms/step - loss: 0.0567 - accuracy: 0.9804
# Epoch 94/200
# 11/11 [==============================] - 0s 3ms/step - loss: 0.0500 - accuracy: 0.9804
# Epoch 95/200
# 11/11 [==============================] - 0s 2ms/step - loss: 0.0372 - accuracy: 1.0000
# Epoch 96/200
# 11/11 [==============================] - 0s 2ms/step - loss: 0.0226 - accuracy: 1.0000
# Epoch 97/200
# 11/11 [==============================] - 0s 3ms/step - loss: 0.0966 - accuracy: 0.9804
# Epoch 98/200
# 11/11 [==============================] - 0s 3ms/step - loss: 0.0634 - accuracy: 0.9608
# Epoch 99/200
# 11/11 [==============================] - 0s 3ms/step - loss: 0.0335 - accuracy: 1.0000
# Epoch 100/200
# 11/11 [==============================] - 0s 3ms/step - loss: 0.0798 - accuracy: 0.9804
# Epoch 101/200
# 11/11 [==============================] - 0s 3ms/step - loss: 0.0155 - accuracy: 1.0000
# Epoch 102/200
# 11/11 [==============================] - 0s 2ms/step - loss: 0.0409 - accuracy: 0.9804
# Epoch 103/200
# 11/11 [==============================] - 0s 2ms/step - loss: 0.1197 - accuracy: 0.9608
# Epoch 104/200
# 11/11 [==============================] - 0s 2ms/step - loss: 0.0320 - accuracy: 1.0000
# Epoch 105/200
# 11/11 [==============================] - 0s 2ms/step - loss: 0.0405 - accuracy: 1.0000
# Epoch 106/200
# 11/11 [==============================] - 0s 2ms/step - loss: 0.0718 - accuracy: 0.9804
# Epoch 107/200
# 11/11 [==============================] - 0s 3ms/step - loss: 0.0155 - accuracy: 1.0000
# Epoch 108/200
# 11/11 [==============================] - 0s 3ms/step - loss: 0.0451 - accuracy: 1.0000
# Epoch 109/200
# 11/11 [==============================] - 0s 3ms/step - loss: 0.0500 - accuracy: 1.0000
# Epoch 110/200
# 11/11 [==============================] - 0s 3ms/step - loss: 0.0493 - accuracy: 1.0000
# Epoch 111/200
# 11/11 [==============================] - 0s 3ms/step - loss: 0.0535 - accuracy: 0.9804
# Epoch 112/200
# 11/11 [==============================] - 0s 2ms/step - loss: 0.0174 - accuracy: 1.0000
# Epoch 113/200
# 11/11 [==============================] - 0s 2ms/step - loss: 0.0808 - accuracy: 0.9804
# Epoch 114/200
# 11/11 [==============================] - 0s 2ms/step - loss: 0.0382 - accuracy: 0.9804
# Epoch 115/200
# 11/11 [==============================] - 0s 2ms/step - loss: 0.0564 - accuracy: 0.9804
# Epoch 116/200
# 11/11 [==============================] - 0s 2ms/step - loss: 0.0551 - accuracy: 0.9804
# Epoch 117/200
# 11/11 [==============================] - 0s 3ms/step - loss: 0.0663 - accuracy: 0.9804
# Epoch 118/200
# 11/11 [==============================] - 0s 3ms/step - loss: 0.0623 - accuracy: 0.9804
# Epoch 119/200
# 11/11 [==============================] - 0s 2ms/step - loss: 0.0372 - accuracy: 0.9804
# Epoch 120/200
# 11/11 [==============================] - 0s 3ms/step - loss: 0.0817 - accuracy: 0.9608
# Epoch 121/200
# 11/11 [==============================] - 0s 2ms/step - loss: 0.0168 - accuracy: 1.0000
# Epoch 122/200
# 11/11 [==============================] - 0s 3ms/step - loss: 0.0432 - accuracy: 1.0000
# Epoch 123/200
# 11/11 [==============================] - 0s 2ms/step - loss: 0.0454 - accuracy: 0.9804
# Epoch 124/200
# 11/11 [==============================] - 0s 3ms/step - loss: 0.0471 - accuracy: 0.9804
# Epoch 125/200
# 11/11 [==============================] - 0s 3ms/step - loss: 0.0087 - accuracy: 1.0000
# Epoch 126/200
# 11/11 [==============================] - 0s 3ms/step - loss: 0.0376 - accuracy: 0.9804
# Epoch 127/200
# 11/11 [==============================] - 0s 3ms/step - loss: 0.0200 - accuracy: 1.0000
# Epoch 128/200
# 11/11 [==============================] - 0s 3ms/step - loss: 0.0375 - accuracy: 1.0000
# Epoch 129/200
# 11/11 [==============================] - 0s 3ms/step - loss: 0.0293 - accuracy: 1.0000
# Epoch 130/200
# 11/11 [==============================] - 0s 3ms/step - loss: 0.1094 - accuracy: 0.9608
# Epoch 131/200
# 11/11 [==============================] - 0s 2ms/step - loss: 0.1637 - accuracy: 0.9804
# Epoch 132/200
# 11/11 [==============================] - 0s 3ms/step - loss: 0.0196 - accuracy: 1.0000
# Epoch 133/200
# 11/11 [==============================] - 0s 2ms/step - loss: 0.0115 - accuracy: 1.0000
# Epoch 134/200
# 11/11 [==============================] - 0s 3ms/step - loss: 0.0299 - accuracy: 1.0000
# Epoch 135/200
# 11/11 [==============================] - 0s 2ms/step - loss: 0.0496 - accuracy: 1.0000
# Epoch 136/200
# 11/11 [==============================] - 0s 3ms/step - loss: 0.0556 - accuracy: 0.9804
# Epoch 137/200
# 11/11 [==============================] - 0s 2ms/step - loss: 0.0320 - accuracy: 0.9804
# Epoch 138/200
# 11/11 [==============================] - 0s 3ms/step - loss: 0.0760 - accuracy: 0.9804
# Epoch 139/200
# 11/11 [==============================] - 0s 2ms/step - loss: 0.0258 - accuracy: 1.0000
# Epoch 140/200
# 11/11 [==============================] - 0s 2ms/step - loss: 0.0376 - accuracy: 1.0000
# Epoch 141/200
# 11/11 [==============================] - 0s 2ms/step - loss: 0.0238 - accuracy: 1.0000
# Epoch 142/200
# 11/11 [==============================] - 0s 2ms/step - loss: 0.0160 - accuracy: 1.0000
# Epoch 143/200
# 11/11 [==============================] - 0s 2ms/step - loss: 0.0176 - accuracy: 1.0000
# Epoch 144/200
# 11/11 [==============================] - 0s 2ms/step - loss: 0.0246 - accuracy: 1.0000
# Epoch 145/200
# 11/11 [==============================] - 0s 2ms/step - loss: 0.0290 - accuracy: 1.0000
# Epoch 146/200
# 11/11 [==============================] - 0s 3ms/step - loss: 0.0256 - accuracy: 1.0000
# Epoch 147/200
# 11/11 [==============================] - 0s 2ms/step - loss: 0.0568 - accuracy: 0.9608
# Epoch 148/200
# 11/11 [==============================] - 0s 3ms/step - loss: 0.0023 - accuracy: 1.0000
# Epoch 149/200
# 11/11 [==============================] - 0s 2ms/step - loss: 0.0429 - accuracy: 1.0000
# Epoch 150/200
# 11/11 [==============================] - 0s 4ms/step - loss: 0.0511 - accuracy: 1.0000
# Epoch 151/200
# 11/11 [==============================] - 0s 2ms/step - loss: 0.0284 - accuracy: 1.0000
# Epoch 152/200
# 11/11 [==============================] - 0s 2ms/step - loss: 0.0554 - accuracy: 0.9804
# Epoch 153/200
# 11/11 [==============================] - 0s 2ms/step - loss: 0.0966 - accuracy: 0.9804
# Epoch 154/200
# 11/11 [==============================] - 0s 2ms/step - loss: 0.0199 - accuracy: 0.9804
# Epoch 155/200
# 11/11 [==============================] - 0s 3ms/step - loss: 0.0581 - accuracy: 0.9804
# Epoch 156/200
# 11/11 [==============================] - 0s 3ms/step - loss: 0.0240 - accuracy: 1.0000
# Epoch 157/200
# 11/11 [==============================] - 0s 2ms/step - loss: 0.1139 - accuracy: 0.9608
# Epoch 158/200
# 11/11 [==============================] - 0s 3ms/step - loss: 0.0207 - accuracy: 1.0000
# Epoch 159/200
# 11/11 [==============================] - 0s 2ms/step - loss: 0.0647 - accuracy: 0.9804
# Epoch 160/200
# 11/11 [==============================] - 0s 2ms/step - loss: 0.0230 - accuracy: 1.0000
# Epoch 161/200
# 11/11 [==============================] - 0s 3ms/step - loss: 0.0208 - accuracy: 1.0000
# Epoch 162/200
# 11/11 [==============================] - 0s 3ms/step - loss: 0.0068 - accuracy: 1.0000
# Epoch 163/200
# 11/11 [==============================] - 0s 2ms/step - loss: 0.0557 - accuracy: 0.9804
# Epoch 164/200
# 11/11 [==============================] - 0s 3ms/step - loss: 0.0371 - accuracy: 0.9804
# Epoch 165/200
# 11/11 [==============================] - 0s 2ms/step - loss: 0.0181 - accuracy: 1.0000
# Epoch 166/200
# 11/11 [==============================] - 0s 2ms/step - loss: 0.0137 - accuracy: 1.0000
# Epoch 167/200
# 11/11 [==============================] - 0s 2ms/step - loss: 0.0127 - accuracy: 1.0000
# Epoch 168/200
# 11/11 [==============================] - 0s 3ms/step - loss: 0.0305 - accuracy: 0.9804
# Epoch 169/200
# 11/11 [==============================] - 0s 3ms/step - loss: 0.0701 - accuracy: 0.9804
# Epoch 170/200
# 11/11 [==============================] - 0s 2ms/step - loss: 0.0348 - accuracy: 0.9804
# Epoch 171/200
# 11/11 [==============================] - 0s 2ms/step - loss: 0.0115 - accuracy: 1.0000
# Epoch 172/200
# 11/11 [==============================] - 0s 3ms/step - loss: 0.0176 - accuracy: 1.0000
# Epoch 173/200
# 11/11 [==============================] - 0s 3ms/step - loss: 0.0203 - accuracy: 1.0000
# Epoch 174/200
# 11/11 [==============================] - 0s 2ms/step - loss: 0.0197 - accuracy: 1.0000
# Epoch 175/200
# 11/11 [==============================] - 0s 2ms/step - loss: 0.0376 - accuracy: 0.9804
# Epoch 176/200
# 11/11 [==============================] - 0s 3ms/step - loss: 0.0098 - accuracy: 1.0000
# Epoch 177/200
# 11/11 [==============================] - 0s 3ms/step - loss: 0.0065 - accuracy: 1.0000
# Epoch 178/200
# 11/11 [==============================] - 0s 2ms/step - loss: 0.0150 - accuracy: 1.0000
# Epoch 179/200
# 11/11 [==============================] - 0s 2ms/step - loss: 0.0225 - accuracy: 1.0000
# Epoch 180/200
# 11/11 [==============================] - 0s 2ms/step - loss: 0.0637 - accuracy: 0.9804
# Epoch 181/200
# 11/11 [==============================] - 0s 2ms/step - loss: 0.0120 - accuracy: 1.0000
# Epoch 182/200
# 11/11 [==============================] - 0s 3ms/step - loss: 0.0041 - accuracy: 1.0000
# Epoch 183/200
# 11/11 [==============================] - 0s 3ms/step - loss: 0.0342 - accuracy: 0.9804
# Epoch 184/200
# 11/11 [==============================] - 0s 3ms/step - loss: 0.0573 - accuracy: 0.9804
# Epoch 185/200
# 11/11 [==============================] - 0s 3ms/step - loss: 0.0200 - accuracy: 1.0000
# Epoch 186/200
# 11/11 [==============================] - 0s 3ms/step - loss: 0.0237 - accuracy: 1.0000
# Epoch 187/200
# 11/11 [==============================] - 0s 3ms/step - loss: 0.0480 - accuracy: 0.9804
# Epoch 188/200
# 11/11 [==============================] - 0s 3ms/step - loss: 0.0138 - accuracy: 1.0000
# Epoch 189/200
# 11/11 [==============================] - 0s 3ms/step - loss: 0.0639 - accuracy: 0.9804
# Epoch 190/200
# 11/11 [==============================] - 0s 3ms/step - loss: 0.0325 - accuracy: 0.9804
# Epoch 191/200
# 11/11 [==============================] - 0s 3ms/step - loss: 0.0149 - accuracy: 1.0000
# Epoch 192/200
# 11/11 [==============================] - 0s 3ms/step - loss: 0.0328 - accuracy: 0.9804
# Epoch 193/200
# 11/11 [==============================] - 0s 3ms/step - loss: 0.0112 - accuracy: 1.0000
# Epoch 194/200
# 11/11 [==============================] - 0s 2ms/step - loss: 0.0089 - accuracy: 1.0000
# Epoch 195/200
# 11/11 [==============================] - 0s 3ms/step - loss: 0.0081 - accuracy: 1.0000
# Epoch 196/200
# 11/11 [==============================] - 0s 2ms/step - loss: 0.0232 - accuracy: 1.0000
# Epoch 197/200
# 11/11 [==============================] - 0s 3ms/step - loss: 0.0302 - accuracy: 1.0000
# Epoch 198/200
# 11/11 [==============================] - 0s 2ms/step - loss: 0.0071 - accuracy: 1.0000
# Epoch 199/200
# 11/11 [==============================] - 0s 2ms/step - loss: 0.0698 - accuracy: 0.9804
# Epoch 200/200
# 11/11 [==============================] - 0s 2ms/step - loss: 0.0115 - accuracy: 1.0000
# model created

# %%
import nltk
from nltk.stem import WordNetLemmatizer
lemmatizer = WordNetLemmatizer()
import pickle
import numpy as np
from keras.models import load_model
model = load_model('chatbot_model.h5')
import json
import random
intents = json.loads(open('intents.json').read())
words = pickle.load(open('words.pkl','rb'))
classes = pickle.load(open('classes.pkl','rb'))

# %%
def clean_up_sentence(sentence):
    # tokenize the pattern - split words into array
    sentence_words = nltk.word_tokenize(sentence)
    # stem each word - create short form for word
    sentence_words = [lemmatizer.lemmatize(word.lower()) for word in sentence_words]
    return sentence_words
# return bag of words array: 0 or 1 for each word in the bag that exists in the sentence
def bow(sentence, words, show_details=True):
    # tokenize the pattern
    sentence_words = clean_up_sentence(sentence)
    # bag of words - matrix of N words, vocabulary matrix
    bag = [0]*len(words) 
    for s in sentence_words:
        for i,w in enumerate(words):
            if w == s: 
                # assign 1 if current word is in the vocabulary position
                bag[i] = 1
                if show_details:
                    print ("found in bag: %s" % w)
    return(np.array(bag))
def predict_class(sentence, model):
    # filter out predictions below a threshold
    p = bow(sentence, words,show_details=False)
    res = model.predict(np.array([p]))[0]
    ERROR_THRESHOLD = 0.25
    results = [[i,r] for i,r in enumerate(res) if r>ERROR_THRESHOLD]
    # sort by strength of probability
    results.sort(key=lambda x: x[1], reverse=True)
    return_list = []
    for r in results:
        return_list.append({"intent": classes[r[0]], "probability": str(r[1])})
    return return_list

# %%
def getResponse(ints, intents_json):
    tag = ints[0]['intent']
    list_of_intents = intents_json['intents']
    for i in list_of_intents:
        if(i['tag']== tag):
            result = random.choice(i['responses'])
            break
    return result
def chatbot_response(text):
    ints = predict_class(text, model)
    res = getResponse(ints, intents)
    return res

# %%
#Creating GUI with tkinter
import tkinter
from tkinter import *
def send():
    msg = EntryBox.get("1.0",'end-1c').strip()
    EntryBox.delete("0.0",END)
    if msg != '':
        ChatLog.config(state=NORMAL)
        ChatLog.insert(END, "You: " + msg + '\n\n')
        ChatLog.config(foreground="#442265", font=("Verdana", 12 ))
        res = chatbot_response(msg)
        ChatLog.insert(END, "Bot: " + res + '\n\n')
        ChatLog.config(state=DISABLED)
        ChatLog.yview(END)
base = Tk()
base.title("Hello")
base.geometry("400x500")
base.resizable(width=FALSE, height=FALSE)
#Create Chat window
ChatLog = Text(base, bd=0, bg="white", height="8", width="50", font="Arial",)
ChatLog.config(state=DISABLED)
#Bind scrollbar to Chat window
scrollbar = Scrollbar(base, command=ChatLog.yview, cursor="heart")
ChatLog['yscrollcommand'] = scrollbar.set
#Create Button to send message
SendButton = Button(base, font=("Verdana",12,'bold'), text="Send", width="12", height=5,
                    bd=0, bg="#32de97", activebackground="#3c9d9b",fg='#ffffff',
                    command= send )
#Create the box to enter message
EntryBox = Text(base, bd=0, bg="white",width="29", height="5", font="Arial")
#EntryBox.bind("<Return>", send)
#Place all components on the screen
scrollbar.place(x=376,y=6, height=386)
ChatLog.place(x=6,y=6, height=386, width=370)
EntryBox.place(x=128, y=401, height=90, width=265)
SendButton.place(x=6, y=401, height=90)
base.mainloop()
